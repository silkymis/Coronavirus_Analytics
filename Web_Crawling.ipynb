# %%
from datetime import date
today = date.today()

d = today.strftime('%m-%d-%y')
print(d)

#https://edition.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-01-14-21/index.html
cnn_url = 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-{}/index.html'.format(d)
print(cnn_url)
# Out:
# 01-18-21
# https://edition.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-01-18-21/index.html

# %%
from bs4 import BeautifulSoup
import requests

html = requests.get(cnn_url).text
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title>Error</title>

# %%
import spacy #for analysing context, countries and topics involved in the news
nlp = spacy.load('en_core_web_sm')

# %%
for link in soup.find_all('h2'):
  print("Headline: {}".format(link.text))
  for ent in nlp(link.text).ents:
    print("\tText: {}, Entity: {}".format(ent.text, ent.label_))
# Out:
# Headline: It could be you, or it could be us, but there's no page here.

# %% [markdown]
# Doing this for multiple URLs individually will be time consuming.\
# Here's an approach to compress the approach for multiple site-crawling.

# %%
#Create variables for all the site URLs
nbc_url='https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url='https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
#create a list of sites, format parsers per site and differentiator per site 
news_urls = [cnn_url, nbc_url, cnbc_rss_url]
parsers = ['html.parser','html.parser','xml']
tags = ['h2','h2','description']
website = ['CNN','NBC','CNBC']

# %%
crawl_len = 0
for url in news_urls:
  #get the response content from each site
  response = requests.get(url)
  soup = BeautifulSoup(response.text, parsers[crawl_len])

  #crawl the relevant content and print it
  for link in soup.find_all(tags[crawl_len]):
    if(len(link.text.split(" ")) > 4):
      print("Headline: {}".format(link.text))
      for ent in nlp(link.text).ents:
        print("\tText: {}, Entity: {}".format(ent.text, ent.label_))

  crawl_len = crawl_len + 1
# Out:
# Headline: It could be you, or it could be us, but there's no page here.
# Headline: Nursing homes make big push to change minds of workers who refused vaccine
# Headline: Fauci: Weeks, not months before new vaccines are submitted for approval
# 	Text: Weeks, Entity: DATE
# 	Text: months, Entity: DATE
# Headline: Black Americans are getting vaccinated at lower rates than white Americans
# 	Text: Americans, Entity: NORP
# 	Text: Americans, Entity: NORP
# Headline: Chaos in a fake vaccine line: Inside NYC's bumpy distribution rollout
# 	Text: NYC, Entity: ORG
# Headline: Los Angeles becomes first county to hit 1 million Covid-19 cases
# 	Text: Los Angeles, Entity: GPE
# 	Text: first, Entity: ORDINAL
# 	Text: 1 million, Entity: CARDINAL
# Headline: Biden to deploy FEMA, National Guard as part of national vaccination plan
# 	Text: FEMA, Entity: ORG
# 	Text: National Guard, Entity: ORG
# Headline: Needle in a haystack: Despite efforts to boost rollout, vaccination rates fail to meet demand
# Headline: Health officials recommend states give Covid vaccine to anyone 65 and older
# 	Text: Covid, Entity: ORG
# 	Text: 65, Entity: CARDINAL
# Headline: Covid vaccine sites need to be ready for rare reactions, officials say
# Headline: Top reads: Inside the vaccine effort
# Headline: States are rolling out vaccination plans. Track the numbers inoculated across the country.
# Headline: Map: Track coronavirus deaths around the world
# Headline: Chart: See the day-by-day size of the coronavirus outbreak
# Headline: Tennis stars forced to quarantine ahead of Australian Open after positive Covid-19 tests
# 	Text: Australian, Entity: NORP
# Headline: Alex Azar resigns as Health and Human Services Secretary, citing Capitol mob
# 	Text: Alex Azar, Entity: PERSON
# 	Text: Health and Human Services, Entity: ORG
# 	Text: Capitol, Entity: ORG
# Headline: India starts world's largest coronavirus vaccination drive
# 	Text: India, Entity: GPE
# Headline: $1,400 checks and a national vaccination program: Biden lays out Covid rescue plan
# 	Text: 1,400, Entity: MONEY
# 	Text: Covid, Entity: PRODUCT
# Headline: The rise of QAnon during the pandemic
# Headline: How the pandemic could force schools in California — and beyond — to rethink education
# 	Text: California, Entity: GPE
# Headline: A look at the back-to-school debate through a teacher’s eyes
# Headline: Member of famed Tuskegee Airmen dies from coronavirus
# 	Text: Tuskegee Airmen, Entity: ORG
# Headline: Beloved Oklahoma physical therapist dies from Covid: 'All she wanted to do was help people'
# 	Text: Oklahoma, Entity: GPE
# Headline: Congressman-elect Luke Letlow dies from Covid complications days before being sworn in
# 	Text: Luke Letlow, Entity: PERSON
# 	Text: Covid complications, Entity: FAC
# Headline: Read and share your anonymous stories about life during the pandemic
# Headline: Doctors, nurses and hospital staff
# Headline: Small businesses and their employees
# Headline: Senior citizens and the elderly
# Headline: What cleaning products kill the coronavirus?
# Headline: Are at-home testing kits available?
# Headline: Can you catch COVID-19 twice?
# Headline: Gyms are eager to reopen, but are they safe?
# Headline: How will coronavirus change the way we fly?
# Headline: Covid Chronicles: A virus-inspired illustrated featureFull series
# Headline: HOW AMERICA GAVE UP — AND HOW WE FIGHT BACK
# Headline: CDC says U.K. coronavirus variant could become predominant strain in U.S. by March
# 	Text: CDC, Entity: ORG
# 	Text: U.K., Entity: GPE
# 	Text: U.S., Entity: GPE
# 	Text: March, Entity: DATE
# Headline: No stockpile? Governors hit Washington as vaccine chokepoints pile up
# 	Text: Washington, Entity: GPE
# Headline: Lyft and Uber want to take you to your vaccination appointment
# 	Text: Uber, Entity: PERSON
# Headline: Brazil's Amazonas state running out of oxygen as COVID-19 surges
# 	Text: Brazil, Entity: GPE
# 	Text: Amazonas, Entity: GPE
# Headline: Thousands of Covid-19 vaccines landing in the garbage
# 	Text: Thousands, Entity: CARDINAL
# Headline: Why a drug therapy that could ease record Covid hospitalizations has gone largely unused
# 	Text: Covid, Entity: NORP
# Headline: California hospital fined over Covid outbreak traced to inflatable Christmas costume
# 	Text: California, Entity: GPE
# 	Text: Covid, Entity: NORP
# 	Text: Christmas, Entity: DATE
# Headline: In final transition days, Biden team gets access to critical Covid vaccine data
# 	Text: transition days, Entity: DATE
# 	Text: Covid, Entity: PRODUCT
# Headline: Automakers forced to cut production amid global shortage of computer chips
# Headline: Wisconsin pharmacist accused of spoiling Covid-19 vaccine has license suspended
# 	Text: Wisconsin, Entity: GPE
# Headline: Weekly initial jobless claims soar to 965,000
# 	Text: Weekly, Entity: DATE
# 	Text: 965,000, Entity: CARDINAL
# Headline: WHO team arrives in Wuhan to investigate pandemic origins
# 	Text: Wuhan, Entity: GPE
# Headline: Latino, Black children twice as likely to endure multiple Covid-related hardships
# Headline: Jan. 14 Coronavirus updates: China reports first coronavirus death since May
# 	Text: Jan. 14, Entity: DATE
# 	Text: Coronavirus, Entity: ORG
# 	Text: China, Entity: GPE
# 	Text: first, Entity: ORDINAL
# 	Text: May, Entity: DATE
# Headline: It's been months since the first U.S. coronavirus death. Here's a look at some of the lives lost.
# 	Text: months, Entity: DATE
# 	Text: first, Entity: ORDINAL
# 	Text: U.S., Entity: GPE
# Headline: Millions are now out of work. Many wonder if there will be a job to go back to.
# 	Text: Millions, Entity: CARDINAL
# Headline: Latest news for health care.
# Headline: Gross domestic product grew by 6.5% in the fourth quarter from a year ago, official data from National Bureau of Statistics showed.
# 	Text: 6.5%, Entity: PERCENT
# 	Text: the fourth quarter, Entity: DATE
# 	Text: a year ago, Entity: DATE
# 	Text: National Bureau of Statistics, Entity: ORG
# Headline: "One thing that's clear is that the issue of getting 100 million doses in the first 100 days is absolutely a doable thing," Dr. Anthony Fauci said on Sunday.
# 	Text: One, Entity: CARDINAL
# 	Text: 100 million, Entity: CARDINAL
# 	Text: the first 100 days, Entity: DATE
# 	Text: Anthony Fauci, Entity: PERSON
# 	Text: Sunday, Entity: DATE
# Headline: Democratic governors criticized the Trump admin for apparently misleading public health officials about holding a stockpile of Covid-19 vaccines in reserve.
# 	Text: Democratic, Entity: NORP
# 	Text: Trump, Entity: PRODUCT
# Headline: Azar's resignation came after U.S. Transportation Secretary Elaine Chao, another Cabinet member, and several other Trump administration officials resigned.
# 	Text: Azar, Entity: PERSON
# 	Text: U.S., Entity: GPE
# 	Text: Transportation, Entity: ORG
# 	Text: Elaine Chao, Entity: PERSON
# 	Text: Cabinet, Entity: ORG
# 	Text: Trump, Entity: PERSON
# Headline: UnitedHealthcare is expanding its telehealth plans for employers to include virtual primary care, a move which Amazon has also explored
# 	Text: UnitedHealthcare, Entity: ORG
# 	Text: Amazon, Entity: ORG
# Headline: The Biden administration will also "quickly jumpstart" efforts to make the vaccines available at local pharmacies across the U.S.
# 	Text: Biden, Entity: PERSON
# 	Text: U.S., Entity: GPE
# Headline: With global deaths reaching 2 million and new strains of the virus appearing, world leaders need to do all they can to curb infections, the WHO said.
# 	Text: 2 million, Entity: CARDINAL
# 	Text: WHO, Entity: ORG
# Headline: "The modeled trajectory of this variant in the U.S. exhibits rapid growth in early 2021, becoming the predominant variant in March," a new CDC study says.
# 	Text: U.S., Entity: GPE
# 	Text: early 2021, Entity: DATE
# 	Text: March, Entity: DATE
# 	Text: CDC, Entity: ORG
# Headline: New York Gov. Andrew Cuomo is holding a press briefing on the coronavirus Friday as the state continues to roll out coronavirus vaccines.
# 	Text: New York, Entity: GPE
# 	Text: Andrew Cuomo, Entity: PERSON
# 	Text: Friday, Entity: DATE
# Headline: News of the variant in Brazil comes after two separate mutant strains of the virus were discovered in the U.K. and South Africa earlier this year.
# 	Text: Brazil, Entity: GPE
# 	Text: two, Entity: CARDINAL
# 	Text: U.K., Entity: GPE
# 	Text: South Africa, Entity: GPE
# 	Text: earlier this year, Entity: DATE
# Headline: Pfizer will temporarily reduce the number of doses of its coronavirus vaccine being delivered to Europe.
# 	Text: Pfizer, Entity: ORG
# 	Text: Europe, Entity: LOC
# Headline: Dow futures fell Friday, with Dow-stock JPMorgan providing limited support after reporting better-than-expected quarterly earnings and revenue.
# 	Text: Friday, Entity: DATE
# 	Text: JPMorgan, Entity: ORG
# 	Text: quarterly, Entity: DATE
# Headline: ATAI Life Science, a Peter Thiel-backed start-up, has taken a majority stake in Recognify, a company that is developing drugs to help treat schizophrenia.
# 	Text: ATAI Life Science, Entity: ORG
# 	Text: Peter Thiel-backed, Entity: PERSON
# 	Text: Recognify, Entity: ORG
# Headline: Top U.S. health officials said Covid antibody drugs are being underutilized, and they urged hospitals to prescribe the drugs much more frequently.
# 	Text: U.S., Entity: GPE
# 	Text: Covid, Entity: NORP
# Headline: Beijing remains on alert for a resurgence of Covid-19 infections as the neighboring province of Hebei continues to report new cases every day.
# 	Text: Beijing, Entity: GPE
# 	Text: Hebei, Entity: GPE
# 	Text: every day, Entity: DATE
# Headline: Sinopharm, a state-owned giant behind China's coronavirus vaccine development, announced its chairman left the board as of Tuesday.
# 	Text: China, Entity: GPE
# 	Text: Tuesday, Entity: DATE
# Headline: The booklet would offer vaccinated individuals significant freedom from Covid-19 safety restrictions.
# Headline: Dr. Scott Gottlieb warned of a potentially dire spring and summer without protective immunity as new, highly transmissible Covid variants appear globally.
# 	Text: Scott Gottlieb, Entity: PERSON
# 	Text: spring, Entity: DATE
# 	Text: summer, Entity: DATE
# 	Text: Covid, Entity: NORP
# Headline: "I think a vaccination certificate is something that you should have the right to have, but not be forced to have," ex-CDC Director Dr. Tom Frieden told CNBC.
# 	Text: CDC, Entity: ORG
# 	Text: Tom Frieden, Entity: PERSON
# 	Text: CNBC, Entity: ORG
# Headline: President-elect Biden unveiled a sweeping plan to combat the pandemic in the U.S., which includes investing billions in a nationwide Covid-19 vaccine campaign.
# 	Text: Biden, Entity: PERSON
# 	Text: U.S., Entity: GPE
# 	Text: billions, Entity: CARDINAL
# Headline: Since the disclosure, Siemens Energy has "steadfastly refused" to assure GE that documents containing the trade secrets have been destroyed, the lawsuit says.
# 	Text: Siemens Energy, Entity: ORG
# 	Text: GE, Entity: ORG
# Headline: Moderna is planning to test a booster shot of its Covid-19 vaccine one year after initial vaccination, as duration of protection isn't yet known.
# 	Text: Moderna, Entity: GPE
# 	Text: one year, Entity: DATE
# Headline: The advisory team has had numerous conversations with vaccine makers, among others, about supply issues, said Dr. Celine Gounder.
# 	Text: Celine Gounder, Entity: PERSON
# Headline: Gov. Andrew Cuomo said if the government is unable to meet the demand, it could cause people to lose "belief in the competence of government."
# 	Text: Andrew Cuomo, Entity: PERSON
# Headline: A digital Covid vaccination passport is being jointly developed by a group of health and technology companies including Microsoft and Salesforce.
# 	Text: Microsoft, Entity: ORG
# 	Text: Salesforce, Entity: ORG
# Headline: The former Food and Drug Administration commissioner said the advice is particularly important for the elderly, who are at higher risk of death from Covid.
#
# 	Text: Food and Drug Administration, Entity: ORG
# 	Text: Covid, Entity: PRODUCT
# Headline: Delta lost a record $12.39 billion in 2020 but is setting its sights on a recovery in 2021 even though it expects more difficult months ahead.
# 	Text: Delta, Entity: ORG
# 	Text: a record $12.39 billion, Entity: MONEY
# 	Text: 2020, Entity: DATE
# 	Text: 2021, Entity: DATE
# 	Text: months ahead, Entity: DATE
# Headline: Dow and S&P 500 futures rose but Nasdaq futures fell Thursday, a day after a mixed session left all three benchmarks less than 1% away from record highs.
# 	Text: Nasdaq, Entity: ORG
# 	Text: Thursday, Entity: DATE
# 	Text: a day, Entity: DATE
# 	Text: three, Entity: CARDINAL
# 	Text: less than 1%, Entity: PERCENT
# Headline: Preliminary findings in Public Health England's SIREN study found antibodies from past Covid infection provide 83% protection against reinfection.
#
# 	Text: Public Health England's, Entity: ORG
# 	Text: SIREN, Entity: ORG
# 	Text: Covid, Entity: NORP
# 	Text: 83%, Entity: PERCENT
# Headline: New Delhi said it plans to inoculate some 300 million people in the first phase of the vaccination exercise, including health-care and other frontline workers.
# 	Text: New Delhi, Entity: GPE
# 	Text: some 300 million, Entity: CARDINAL
# 	Text: first, Entity: ORDINAL

# %% [markdown]
# Crawling and storing data in a dataframe\
# Columns:
# entities, headline, url, website

# %%
crawl_len=0
news_dict=[]
for url in news_urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content,parsers[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):

        entities=[]

        entities=[(ent.text, ent.label_) for ent in nlp(link.text).ents]

        news_dict.append({'website':website[crawl_len],'url': url,'headline':link.text,'entities':entities})
    
    crawl_len=crawl_len+1

# %%
news_dict
# Out:
# [{'entities': [],
#   'headline': "It could be you, or it could be us, but there's no page here.",
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-01-18-21/index.html',
#   'website': 'CNN'},
#  {'entities': [],
#   'headline': 'Nursing homes make big push to change minds of workers who refused vaccine',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Weeks', 'DATE'), ('months', 'DATE')],
#   'headline': 'Fauci: Weeks, not months before new vaccines are submitted for approval',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Americans', 'NORP'), ('Americans', 'NORP')],
#   'headline': 'Black Americans are getting vaccinated at lower rates than white Americans',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('NYC', 'ORG')],
#   'headline': "Chaos in a fake vaccine line: Inside NYC's bumpy distribution rollout",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Los Angeles', 'GPE'),
#    ('first', 'ORDINAL'),
#    ('1 million', 'CARDINAL')],
#   'headline': 'Los Angeles becomes first county to hit 1 million Covid-19 cases',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('FEMA', 'ORG'), ('National Guard', 'ORG')],
#   'headline': 'Biden to deploy FEMA, National Guard as part of national vaccination plan',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Needle in a haystack: Despite efforts to boost rollout, vaccination rates fail to meet demand',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid', 'ORG'), ('65', 'CARDINAL')],
#   'headline': 'Health officials recommend states give Covid vaccine to anyone 65 and older',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid vaccine sites need to be ready for rare reactions, officials say',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Top reads: Inside the vaccine effort',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'States are rolling out vaccination plans. Track the numbers inoculated across the country.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Map: Track coronavirus deaths around the world',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Chart: See the day-by-day size of the coronavirus outbreak',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Australian', 'NORP')],
#   'headline': 'Tennis stars forced to quarantine ahead of Australian Open after positive Covid-19 tests',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Alex Azar', 'PERSON'),
#    ('Health and Human Services', 'ORG'),
#    ('Capitol', 'ORG')],
#   'headline': 'Alex Azar resigns as Health and Human Services Secretary, citing Capitol mob',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('India', 'GPE')],
#   'headline': "India starts world's largest coronavirus vaccination drive",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('1,400', 'MONEY'), ('Covid', 'PRODUCT')],
#   'headline': '$1,400 checks and a national vaccination program: Biden lays out Covid rescue plan',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'The rise of QAnon during the pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('California', 'GPE')],
#   'headline': 'How the pandemic could force schools in California — and beyond — to rethink education',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'A look at the back-to-school debate through a teacher’s eyes',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Tuskegee Airmen', 'ORG')],
#   'headline': 'Member of famed Tuskegee Airmen dies from coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Oklahoma', 'GPE')],
#   'headline': "Beloved Oklahoma physical therapist dies from Covid: 'All she wanted to do was help people'",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Luke Letlow', 'PERSON'), ('Covid complications', 'FAC')],
#   'headline': 'Congressman-elect Luke Letlow dies from Covid complications days before being sworn in',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Read and share your anonymous stories about life during the pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Doctors, nurses and hospital staff',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Small businesses and their employees',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Senior citizens and the elderly',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'What cleaning products kill the coronavirus?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Are at-home testing kits available?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Can you catch COVID-19 twice? ',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Gyms are eager to reopen, but are they safe?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'How will coronavirus change the way we fly?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid Chronicles: A virus-inspired illustrated featureFull series',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'HOW AMERICA GAVE UP — AND HOW WE FIGHT BACK',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('CDC', 'ORG'),
#    ('U.K.', 'GPE'),
#    ('U.S.', 'GPE'),
#    ('March', 'DATE')],
#   'headline': 'CDC says U.K. coronavirus variant could become predominant strain in U.S. by March',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Washington', 'GPE')],
#   'headline': 'No stockpile? Governors hit Washington as vaccine chokepoints pile up',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Uber', 'PERSON')],
#   'headline': 'Lyft and Uber want to take you to your vaccination appointment',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Brazil', 'GPE'), ('Amazonas', 'GPE')],
#   'headline': "Brazil's Amazonas state running out of oxygen as COVID-19 surges",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Thousands', 'CARDINAL')],
#   'headline': 'Thousands of Covid-19 vaccines landing in the garbage',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid', 'NORP')],
#   'headline': 'Why a drug therapy that could ease record Covid hospitalizations has gone largely unused',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('California', 'GPE'),
#    ('Covid', 'NORP'),
#    ('Christmas', 'DATE')],
#   'headline': 'California hospital fined over Covid outbreak traced to inflatable Christmas costume',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('transition days', 'DATE'), ('Covid', 'PRODUCT')],
#   'headline': 'In final transition days, Biden team gets access to critical Covid vaccine data',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Automakers forced to cut production amid global shortage of computer chips',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Wisconsin', 'GPE')],
#   'headline': 'Wisconsin pharmacist accused of spoiling Covid-19 vaccine has license suspended',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Weekly', 'DATE'), ('965,000', 'CARDINAL')],
#   'headline': 'Weekly initial jobless claims soar to 965,000',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Wuhan', 'GPE')],
#   'headline': 'WHO team arrives in Wuhan to investigate pandemic origins',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latino, Black children twice as likely to endure multiple Covid-related hardships',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Jan. 14', 'DATE'),
#    ('Coronavirus', 'ORG'),
#    ('China', 'GPE'),
#    ('first', 'ORDINAL'),
#    ('May', 'DATE')],
#   'headline': 'Jan. 14 Coronavirus updates: China reports first coronavirus death since May',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('months', 'DATE'), ('first', 'ORDINAL'), ('U.S.', 'GPE')],
#   'headline': "It's been months since the first U.S. coronavirus death. Here's a look at some of the lives lost.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Millions', 'CARDINAL')],
#   'headline': 'Millions are now out of work. Many wonder if there will be a job to go back to.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latest news for health care. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('6.5%', 'PERCENT'),
#    ('the fourth quarter', 'DATE'),
#    ('a year ago', 'DATE'),
#    ('National Bureau of Statistics', 'ORG')],
#   'headline': 'Gross domestic product\xa0grew by 6.5% in the fourth quarter from a year ago, official data from National Bureau of Statistics showed.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('One', 'CARDINAL'),
#    ('100 million', 'CARDINAL'),
#    ('the first 100 days', 'DATE'),
#    ('Anthony Fauci', 'PERSON'),
#    ('Sunday', 'DATE')],
#   'headline': '"One thing that\'s clear is that the issue of getting 100 million doses in the first 100 days is absolutely a doable thing," Dr. Anthony Fauci said on Sunday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Democratic', 'NORP'), ('Trump', 'PRODUCT')],
#   'headline': 'Democratic governors criticized the Trump admin for apparently misleading public health officials about holding a stockpile of Covid-19 vaccines in reserve. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Azar', 'PERSON'),
#    ('U.S.', 'GPE'),
#    ('Transportation', 'ORG'),
#    ('Elaine Chao', 'PERSON'),
#    ('Cabinet', 'ORG'),
#    ('Trump', 'PERSON')],
#   'headline': "Azar's resignation came after U.S. Transportation Secretary Elaine Chao, another Cabinet member, and several other Trump administration officials resigned.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('UnitedHealthcare', 'ORG'), ('Amazon', 'ORG')],
#   'headline': 'UnitedHealthcare is expanding its telehealth plans for employers to include virtual primary care, a move which Amazon has also explored  ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Biden', 'PERSON'), ('U.S.', 'GPE')],
#   'headline': 'The Biden administration will also "quickly jumpstart" efforts to make the vaccines available at local pharmacies across the U.S.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('2 million', 'CARDINAL'), ('WHO', 'ORG')],
#   'headline': 'With global deaths reaching 2 million and new strains of the virus appearing, world leaders need to do all they can to curb infections, the WHO said. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('U.S.', 'GPE'),
#    ('early 2021', 'DATE'),
#    ('March', 'DATE'),
#    ('CDC', 'ORG')],
#   'headline': '"The modeled trajectory of this variant in the U.S. exhibits\xa0rapid growth in early 2021, becoming the predominant variant in March," a new CDC study says. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New York', 'GPE'),
#    ('Andrew Cuomo', 'PERSON'),
#    ('Friday', 'DATE')],
#   'headline': 'New York Gov. Andrew Cuomo is holding a press briefing on the coronavirus Friday as the state continues to roll out coronavirus vaccines. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Brazil', 'GPE'),
#    ('two', 'CARDINAL'),
#    ('U.K.', 'GPE'),
#    ('South Africa', 'GPE'),
#    ('earlier this year', 'DATE')],
#   'headline': 'News of the variant in Brazil comes after two separate mutant strains of the virus were discovered in the U.K. and South Africa earlier this year. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Pfizer', 'ORG'), ('Europe', 'LOC')],
#   'headline': 'Pfizer will temporarily reduce the number of doses of its coronavirus vaccine being delivered to Europe.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Friday', 'DATE'), ('JPMorgan', 'ORG'), ('quarterly', 'DATE')],
#   'headline': 'Dow futures fell Friday, with Dow-stock JPMorgan providing limited support after reporting better-than-expected quarterly earnings and revenue.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('ATAI Life Science', 'ORG'),
#    ('Peter Thiel-backed', 'PERSON'),
#    ('Recognify', 'ORG')],
#   'headline': 'ATAI Life Science, a Peter Thiel-backed start-up, has taken a majority stake in Recognify, a company that is developing drugs to help treat schizophrenia.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('U.S.', 'GPE'), ('Covid', 'NORP')],
#   'headline': 'Top U.S. health officials said Covid antibody drugs are being underutilized, and they urged hospitals to prescribe the drugs much more frequently.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Beijing', 'GPE'), ('Hebei', 'GPE'), ('every day', 'DATE')],
#   'headline': 'Beijing remains on alert for a resurgence of Covid-19 infections as the neighboring province of Hebei continues to report new cases every day.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('China', 'GPE'), ('Tuesday', 'DATE')],
#   'headline': "Sinopharm, a state-owned giant behind China's coronavirus vaccine development, announced its chairman left the board as of Tuesday.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'The booklet would offer vaccinated individuals significant freedom from Covid-19 safety restrictions. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Scott Gottlieb', 'PERSON'),
#    ('spring', 'DATE'),
#    ('summer', 'DATE'),
#    ('Covid', 'NORP')],
#   'headline': 'Dr. Scott Gottlieb warned of a potentially dire spring and summer without protective immunity as new, highly transmissible Covid variants appear globally.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('CDC', 'ORG'), ('Tom Frieden', 'PERSON'), ('CNBC', 'ORG')],
#   'headline': '"I think a vaccination certificate is something that you should have the right to have, but not be forced to have," ex-CDC Director Dr. Tom Frieden told CNBC.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Biden', 'PERSON'), ('U.S.', 'GPE'), ('billions', 'CARDINAL')],
#   'headline': 'President-elect Biden unveiled a sweeping plan to combat the pandemic in the U.S., which includes investing billions in a nationwide Covid-19 vaccine campaign.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Siemens Energy', 'ORG'), ('GE', 'ORG')],
#   'headline': 'Since the disclosure, Siemens Energy has "steadfastly refused" to assure GE that documents containing the trade secrets have been destroyed, the lawsuit says.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Moderna', 'GPE'), ('one year', 'DATE')],
#   'headline': "Moderna is planning to test a booster shot of its Covid-19 vaccine one year after initial vaccination, as duration of protection isn't yet known.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Celine Gounder', 'PERSON')],
#   'headline': 'The advisory team has had numerous conversations with vaccine makers, among others, about supply issues, said Dr. Celine Gounder.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Andrew Cuomo', 'PERSON')],
#   'headline': 'Gov. Andrew Cuomo said if the government is unable to meet the demand, it could cause people to lose "belief in the competence of government."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Microsoft', 'ORG'), ('Salesforce', 'ORG')],
#   'headline': 'A digital Covid vaccination passport is being jointly developed by a group of health and technology companies including Microsoft and Salesforce. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Food and Drug Administration', 'ORG'), ('Covid', 'PRODUCT')],
#   'headline': 'The former Food and Drug Administration commissioner said the advice is particularly important for the elderly, who are at higher risk of death from Covid.\n',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Delta', 'ORG'),
#    ('a record $12.39 billion', 'MONEY'),
#    ('2020', 'DATE'),
#    ('2021', 'DATE'),
#    ('months ahead', 'DATE')],
#   'headline': 'Delta lost a record $12.39 billion in 2020 but is setting its sights on a recovery in 2021 even though it expects more difficult months ahead.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Nasdaq', 'ORG'),
#    ('Thursday', 'DATE'),
#    ('a day', 'DATE'),
#    ('three', 'CARDINAL'),
#    ('less than 1%', 'PERCENT')],
#   'headline': 'Dow and S&P 500 futures rose but Nasdaq futures fell Thursday, a day after a mixed session left all three benchmarks less than 1% away from record highs.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [("Public Health England's", 'ORG'),
#    ('SIREN', 'ORG'),
#    ('Covid', 'NORP'),
#    ('83%', 'PERCENT')],
#   'headline': "Preliminary findings in Public Health England's SIREN study found antibodies from past Covid infection provide 83% protection against reinfection.\n",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New Delhi', 'GPE'),
#    ('some 300 million', 'CARDINAL'),
#    ('first', 'ORDINAL')],
#   'headline': 'New Delhi said it plans to inoculate some 300 million people in the first phase of the vaccination exercise, including health-care and other frontline workers. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'}]

# %%
import pandas as pd
news_df = pd.DataFrame(news_dict)
pd.set_option('max_colwidth',800)

news_df.head()
# Out:
#   website  ...                                entities
# 0     CNN  ...                                      []
# 1     NBC  ...                                      []
# 2     NBC  ...         [(Weeks, DATE), (months, DATE)]
# 3     NBC  ...  [(Americans, NORP), (Americans, NORP)]
# 4     NBC  ...                            [(NYC, ORG)]
#
# [5 rows x 4 columns]

# %% [markdown]
# Breaking the entities with list column to different series

# %%
pd.concat([news_df[['website','url','headline']], news_df['entities'].apply(pd.Series)], axis=1)
# Out:
#    website  ...    5
# 0      CNN  ...  NaN
# 1      NBC  ...  NaN
# 2      NBC  ...  NaN
# 3      NBC  ...  NaN
# 4      NBC  ...  NaN
# ..     ...  ...  ...
# 77    CNBC  ...  NaN
# 78    CNBC  ...  NaN
# 79    CNBC  ...  NaN
# 80    CNBC  ...  NaN
# 81    CNBC  ...  NaN
#
# [82 rows x 9 columns]

# %%
news_df.to_csv("web_scraping.csv")
